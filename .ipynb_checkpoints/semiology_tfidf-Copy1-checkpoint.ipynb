# %%
import numpy as np
import pandas as pd
import re
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from collections import Counter
from sklearn.metrics import confusion_matrix, balanced_accuracy_score
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Define preprocessing functions

# General preprocessing
def preprocess_text(text):
    
    # Convert text to lowercase
    text = text.lower()
    
    # remove a special thing
    text = re.sub(r'&gt;',' ',text)
    
    # remove semicolons, ampersands
    text = re.sub(r'[&;-]', ' ', text)
    
    # Remove punctuation and special characters
    text = re.sub(r'[^\w\s]', ' ', text)
    
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    
    # other weird stuff to remove
    text = re.sub(r'\xa0',' ',text)
    
    # other weird stuff to remove
    text = re.sub(r'including aura',' ',text)
    
    start_index = text.find('description of emu evaluation')
    # If the phrase is found, remove it along with the subsequent characters
    if start_index != -1:
        text = text[:start_index]
    
    return text

# Extract just the semiology bits from the templates
def extract_only_semiology(text):
    
    # flexible here
    text = re.sub('subjective semiology (including aura)','subjective semiology',text)
    
    sub_pattern = re.compile(r"(?<=subjective semiology)(.*?)(?=witnesses report)", re.DOTALL)
    sub_matches = sub_pattern.findall(text)
    
    wit_pattern = re.compile(r"(?<=witnesses report)(.*?)(?=duration)", re.DOTALL)
    wit_matches = wit_pattern.findall(text)
    
    dur_pattern = re.compile(r"(?<=duration)(.*?)(?=postictal)", re.DOTALL)
    dur_matches = dur_pattern.findall(text)
    
    post_pattern = re.compile(r"(?<=postictal)(.*?)(?=tongue biting)", re.DOTALL)
    post_matches = post_pattern.findall(text)
    
    if wit_matches or sub_matches or dur_matches or post_matches:
        concatenated_text = ' '.join(sub_matches) + ' '.join(wit_matches) + ' '.join(dur_matches) + ' '.join(post_matches)
        return concatenated_text
    else:
        return text
    
# Other template
def extract_only_semiology2(text):
    
    
    sub_pattern = re.compile(r"(?<=event description)(.*?)(?=age at onset)", re.DOTALL)
    sub_matches = sub_pattern.findall(text)
    
    wit_pattern = re.compile(r"(?<=seizure description)(.*?)(?=age at onset)", re.DOTALL)
    wit_matches = wit_pattern.findall(text)
    
    if wit_matches or sub_matches:
        concatenated_text = ' '.join(sub_matches) + ' '.join(wit_matches)
        return concatenated_text
    else:
        return text
    
def remove_extra_spaces(text):
    # Split the text into words
    words = text.split()
    # Join the words back together with a single space between them
    cleaned_text = ' '.join(words)
    # Remove any remaining extra spaces and newlines
    cleaned_text = cleaned_text.replace('\n', ' ')
    return cleaned_text

# Make a new censored_semiology which censors obvious seizure words
def censor_text(text):
    
    phrases_to_replace = ['spells','spell','fias','seizures','events','event','seizure','fbtcs','btcs','btc','aura','gtc','postictal','ictal','fas']
    
    # Construct a regular expression pattern by joining the phrases with "|" to match any of them
    pattern = '|'.join(re.escape(phrase) for phrase in phrases_to_replace)
    
    # Use the sub() function to replace matched phrases with an empty string
    cleaned_text = re.sub(pattern, '', text)
    
    return cleaned_text

# %%
# Load in and pre-process data

# Load the CSV file into a DataFrame
df1 = pd.read_csv('../data/erin_semiology.csv')

# Handling missing values
df1['semiology'] = df1['semiology'].fillna('')

# Remove patients with non-matching last name
df1 = df1[df1['matching_last_name'] == True]

# Group by patient_id and aggregate semiology
df2 = df1.groupby('patient_id')['semiology'].agg(lambda x: ' '.join(set(x))).reset_index()

# Merge df2 with df1 to retain original columns
df2 = pd.merge(df2, df1.drop_duplicates('patient_id'), on='patient_id', how='left')

# apply all cleaning
df2['clean_semiology'] = df2['semiology_x'].apply(preprocess_text)
#df2['clean_semiology'] = df2['clean_semiology'].apply(extract_only_semiology)
#df2['clean_semiology'] = df2['clean_semiology'].apply(extract_only_semiology2)
df2['clean_semiology'] = df2['clean_semiology'].apply(remove_extra_spaces)

df3 = df2[df2['clean_semiology'] != '']

# Censor text
df3['censored_semiology'] = df3['clean_semiology'].apply(censor_text)
# Out:
# /var/folders/kc/k0vnmns51gx_9t0mb0x8x_7r0000gn/T/ipykernel_4009/3937296961.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['censored_semiology'] = df3['clean_semiology'].apply(censor_text)

# %%
df3
# Out:
#       patient_id                                        semiology_x  \
# 0              0  (1) Bilateral arm twitching lasting 3-4 second...
# 1              1  Semiology: 1. Crying with both arms extended i...
# 3              3  Event #1: possible convulsions  Average freque...
# 4              4  1. Upward deviation of both eyes followed by b...
# 5              5  1. Average frequency: only 6 in lifetime Last ...
# ...          ...                                                ...
# 1129        1130  1. She is continuing with 'black out' episodes...
# 1130        1131  1. Generalized tonic clonic seizures (3 in her...
# 1131        1132  1. BTC, no aura, husband notes lip smacking at...
# 1133        1134  1. "spacing out spells" - sometimes preceded b...
# 1134        1135  1. bilateral body shaking and "losing control"...
#
#      admission_id   ieeg_file_name  matching_last_name  different_dobs  \
# 0         EMU1648  EMU1648_Day03_1                True           False
# 1         EMU1355  EMU1355_Day02_1                True           False
# 3         EMU2080  EMU2080_Day06_1                True           False
# 4         EMU1649  EMU1649_Day04_1                True           False
# 5         EMU1947  EMU1947_Day01_1                True           False
# ...           ...              ...                 ...             ...
# 1129      EMU2351  EMU2351_Day01_1                True           False
# 1130      EMU1827  EMU1827_Day05_1                True           False
# 1131      EMU1828  EMU1828_Day05_1                True           False
# 1133      EMU2352  EMU2352_Day08_1                True           False
# 1134      EMU2078  EMU2078_Day05_1                True           False
#
#      single_diagnosis    bfepidx      epidx single_type epitype single_lat  \
# 0            epilepsy   epilepsy   epilepsy         gen     gen        NaN
# 1            epilepsy   epilepsy   epilepsy         NaN     !!!      right
# 3                both       both       both       focal   focal      right
# 4                pnes       pnes       pnes         NaN     NaN        NaN
# 5            epilepsy   epilepsy   epilepsy         gen     gen        NaN
# ...               ...        ...        ...         ...     ...        ...
# 1129         epilepsy   epilepsy   epilepsy       focal   focal      right
# 1130              NaN  uncertain  uncertain         NaN     NaN        NaN
# 1131         epilepsy   epilepsy   epilepsy       focal   focal       left
# 1133         epilepsy   epilepsy   epilepsy       focal   focal       left
# 1134             both       both       both       focal   focal       left
#
#      epilat single_loc    epiloc ied_yesno ied_type  \
# 0       NaN        NaN       NaN      True     both
# 1     right    frontal   frontal     False      NaN
# 3     right   temporal  temporal      True    focal
# 4       NaN        NaN       NaN     False      NaN
# 5       NaN        NaN       NaN      True    focal
# ...     ...        ...       ...       ...      ...
# 1129  right   temporal  temporal      True    focal
# 1130    NaN        NaN       NaN      True      gen
# 1131   left        NaN       !!!      True     both
# 1133   left   temporal  temporal      True    focal
# 1134   left   temporal  temporal      True      gen
#
#                                             semiology_y  \
# 0     (1) Bilateral arm twitching lasting 3-4 second...
# 1     Semiology: 1. Crying with both arms extended i...
# 3     Event #1: possible convulsions  Average freque...
# 4     1. Upward deviation of both eyes followed by b...
# 5     1. Average frequency: only 6 in lifetime Last ...
# ...                                                 ...
# 1129  1. She is continuing with 'black out' episodes...
# 1130  1. Generalized tonic clonic seizures (3 in her...
# 1131  1. BTC, no aura, husband notes lip smacking at...
# 1133  1. "spacing out spells" - sometimes preceded b...
# 1134  1. bilateral body shaking and "losing control"...
#
#                                         clean_semiology  \
# 0     bilateral arm twitching lasting seconds someti...
# 1     semiology crying with both arms extended in fr...
# 3     event possible convulsions average frequency t...
# 4     upward deviation of both eyes followed by bila...
# 5     average frequency only in lifetime last event ...
# ...                                                 ...
# 1129  she is continuing with black out episodes she ...
# 1130  generalized tonic clonic seizures in her lifet...
# 1131  btc no aura husband notes lip smacking at onse...
# 1133  spacing out spells sometimes preceded by feeli...
# 1134  bilateral body shaking and losing control of h...
#
#                                      censored_semiology
# 0     bilateral arm twitching lasting seconds someti...
# 1     semiology crying with both arms extended in fr...
# 3      possible convulsions average frequency twice ...
# 4     upward deviation of both eyes followed by bila...
# 5     average frequency only in lifetime last  subje...
# ...                                                 ...
# 1129  she is continuing with black out episodes she ...
# 1130  generalized tonic clonic  in her lifetime all ...
# 1131     no  husband notes lip smacking at onset x week
# 1133  spacing out  sometimes preceded by feeling of ...
# 1134  bilateral body shaking and losing control of h...
#
# [770 rows x 20 columns]

# %%
def case_epi():
    pos_label = 'epilepsy'
    neg_label = 'pnes'
    column = 'single_diagnosis'
    return pos_label, neg_label, column
def case_loc():
    pos_label = 'temporal'
    neg_label = 'frontal'
    column = 'single_loc'
    return pos_label, neg_label, column
def case_lat():
    pos_label = 'left'
    neg_label = 'right'
    column = 'single_lat'
    return pos_label, neg_label, column

# The 'switch' dictionary
switch_dict = {
    1: case_epi,
    2: case_loc,
    3: case_lat,
}

# %%
# Restrict and make labels
case_to_handle = 1
pos_label, neg_label, column = switch_dict.get(case_to_handle, 1)()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 # Restrict and make labels
#       2 case_to_handle = 1
# ----> 3 pos_label, neg_label, column = switch_dict.get(case_to_handle, 1)()
#
# TypeError: cannot unpack non-iterable CountVectorizer object

# %%
df4 = df3[df3[column].isin([pos_label,neg_label])]
df4['labels'] = df4[column].apply(lambda x: 1 if x == pos_label else 0)
# Out:
# /var/folders/kc/k0vnmns51gx_9t0mb0x8x_7r0000gn/T/ipykernel_4009/1410150024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['labels'] = df4[column].apply(lambda x: 1 if x == pos_label else 0)

# %%
df = df4
df.shape
# Out:
# (563, 21)

# %%
def case_bow():
    vectorizer = CountVectorizer()
    return vectorizer
def case_tfidf():
    vectorizer = TfidfVectorizer(max_features=1000)
    return vectorizer

# The 'switch' dictionary
switch_dict = {
    1: case_bow,
    2: case_tfidf,
}

# %%
# decide vectorizer
case_to_handle = 2
vectorizer = switch_dict.get(case_to_handle,1)()

# %%
# Fit the vectorizer to the training data and transform it
X = vectorizer.fit_transform(df['censored_semiology']).toarray()

# Get the feature names (i.e., the vocabulary)
feature_names = vectorizer.get_feature_names_out()

# %%
# Define y
y = df['labels']

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# Apply SMOTE
sm = SMOTE()
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# %%
# Train a logistic regression classifier
log_reg = LogisticRegression()
#log_reg = LogisticRegression(penalty='l1', C=1.0, solver='saga', max_iter=1000, random_state=42)
log_reg.fit(X_train_res, y_train_res)
# Out:
# LogisticRegression(max_iter=1000, penalty='l1', random_state=42, solver='saga')

# %%
# Calculate predicted probabilities
y_probs = log_reg.predict_proba(X_test)[:, 1]

# %%
# Calculate the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_probs)

# Calculate the area under the ROC curve
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Predict classes
y_pred = log_reg.predict(X_test)

# Create confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = conf_matrix.ravel()

# Calculate Balanced Accuracy
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

print("Balanced Accuracy:", balanced_accuracy)
# Out:
# Balanced Accuracy: 0.5918039373242265

# %%
# Get the coefficients for each class
coefficients = log_reg.coef_[0]  # Extract coefficients for the binary classification

# Separate features pointing towards class 1 and class 0
features_class_1 = np.argsort(coefficients)[-20:]  # Top 10 features pointing towards class 1
features_class_0 = np.argsort(coefficients)[:20]   # Top 10 features pointing towards class 0

print("Top 10 features pointing towards class 1:")
for idx in reversed(features_class_1):  # Reverse to show the highest first
    print(f"{feature_names[idx]} (Coefficient: {coefficients[idx]:.4f})")

print("\nTop 10 features pointing towards class 0:")
for idx in features_class_0:
    print(f"{feature_names[idx]} (Coefficient: {coefficients[idx]:.4f})")
# Out:
# Top 10 features pointing towards class 1:
# none (Coefficient: 4.2841)
# behavioral (Coefficient: 2.9264)
# occurs (Coefficient: 2.7999)
# then (Coefficient: 2.7888)
# months (Coefficient: 2.4011)
# vu (Coefficient: 2.3696)
# automatisms (Coefficient: 1.7947)
# post (Coefficient: 1.6801)
# his (Coefficient: 1.5736)
# seconds (Coefficient: 1.5275)
# with (Coefficient: 0.8805)
# myoclonus (Coefficient: 0.8316)
# per (Coefficient: 0.7333)
# right (Coefficient: 0.5895)
# nocturnal (Coefficient: 0.3180)
# uncertain (Coefficient: 0.0140)
# generalized (Coefficient: 0.0000)
# generalization (Coefficient: 0.0000)
# gaze (Coefficient: 0.0000)
# gets (Coefficient: 0.0000)
#
# Top 10 features pointing towards class 0:
# eyes (Coefficient: -5.1337)
# shaking (Coefficient: -5.1287)
# her (Coefficient: -4.5256)
# out (Coefficient: -4.3373)
# body (Coefficient: -4.0982)
# paralysis (Coefficient: -3.6180)
# there (Coefficient: -3.5473)
# has (Coefficient: -3.1276)
# onset (Coefficient: -3.0794)
# jerking (Coefficient: -2.6060)
# side (Coefficient: -1.9930)
# described (Coefficient: -1.9480)
# feels (Coefficient: -1.7909)
# stuttering (Coefficient: -1.7419)
# daily (Coefficient: -1.6292)
# minutes (Coefficient: -1.4147)
# see (Coefficient: -1.3942)
# unilateral (Coefficient: -1.3112)
# vertigo (Coefficient: -1.1556)
# times (Coefficient: -1.0711)

# %%
# see highest prob cases of pnes
# Create a DataFrame to store predicted probabilities and original labels
predictions_df = pd.DataFrame({'Probability_1': y_probs, 'Probability_0':1-y_probs,'Actual_Label': y_test})

# Sort instances based on predicted probabilities (descending order)
predictions_df_sorted = predictions_df.sort_values(by='Probability_1', ascending=False)
predictions_df_reverse_sorted = predictions_df.sort_values(by='Probability_0', ascending=False)


# Display instances with the highest probability
top_n = 10  # You can adjust this value to display more or fewer instances
top_1_instances = predictions_df_sorted.head(top_n)
top_0_instances = predictions_df_reverse_sorted.head(top_n)

# Merge the DataFrame containing predicted probabilities with the original DataFrame
top_1_instances_with_text = pd.merge(top_1_instances, df, left_index=True, right_index=True)
top_0_instances_with_text = pd.merge(top_0_instances, df, left_index=True, right_index=True)


# Select relevant columns (e.g., "cleaner_semiology", "Probability_pnes", "Actual_Label")
relevant_columns = ["clean_semiology","censored_semiology", "Probability_0", "Probability_1", "Actual_Label"]
top_1_instances_text = top_1_instances_with_text[relevant_columns]
top_0_instances_text = top_0_instances_with_text[relevant_columns]


# Display instances with the highest probability of being 0 along with their text
print("Cases with the highest probability of being Class 1 and their corresponding text:")
print(top_1_instances_text)

print("Cases with the highest probability of being Class 0 and their corresponding text:")
print(top_0_instances_text)
# Out:
# Cases with the highest probability of being Class 1 and their corresponding text:
#                                         clean_semiology  \
# 457   fias deja vu for seconds then confusion decrea...
# 664   btcs no aura although can be preceded by a few...
# 673   event fias average frequency once last event m...
# 1118  staring spell with drooling daily convulsions ...
# 539   convulsions both nocturnal and awake no aura p...
# 924   focal impaired awareness seizures then tonic a...
# 782   grimace head to right unresponsivness epilepti...
# 1114  stare sweating loss of awareness btc tongue bi...
# 758   event fias average frequency x month last even...
# 1109  focal impaired with secondary generalization s...
#
#                                      censored_semiology  Probability_0  \
# 457    deja vu for seconds then confusion decreased ...       0.063587
# 664    no  although can be preceded by a few days of...       0.088583
# 673     average frequency once last  mid june subjec...       0.112960
# 1118  staring  with drooling daily convulsions none ...       0.115613
# 539   convulsions both nocturnal and awake no  patie...       0.125028
# 924   focal impaired awareness  then tonic and falls...       0.126806
# 782   grimace head to right unresponsivness epilepti...       0.127271
# 1114  stare sweating loss of awareness  tongue bitin...       0.129612
# 758     average frequency x month last  subjective s...       0.130862
# 1109  focal impaired with secondary generalization s...       0.139615
#
#       Probability_1  Actual_Label
# 457        0.936413             1
# 664        0.911417             1
# 673        0.887040             1
# 1118       0.884387             1
# 539        0.874972             1
# 924        0.873194             1
# 782        0.872729             1
# 1114       0.870388             1
# 758        0.869138             1
# 1109       0.860385             1
# Cases with the highest probability of being Class 0 and their corresponding text:
#                                         clean_semiology  \
# 586   patient usually blacks out but sometimes feels...
# 1104  bilateral arm shaking vs full body convulsions...
# 677   gtcs since childhood she noted a fuzzy memory ...
# 79    loss of consciousness body shaking head back a...
# 73    event black out spells average frequency once ...
# 639   convulsion staring arms raise and stiffen and ...
# 122   event wakes up from sleep shaking all over ret...
# 658   seizure type fas subjective semiology she expe...
# 587   feels off wave rushing down her body then full...
# 1071  seizure type convulsion subjective semiology h...
#
#                                      censored_semiology  Probability_0  \
# 586   patient usually blacks out but sometimes feels...       0.823090
# 1104  bilateral arm shaking vs full body convulsions...       0.821851
# 677   s since childhood she noted a fuzzy memory and...       0.820787
# 79    loss of consciousness body shaking head back a...       0.819673
# 73     black out  average frequency once a month las...       0.819219
# 639   convulsion staring arms raise and stiffen and ...       0.798988
# 122    wakes up from sleep shaking all over retained...       0.795769
# 658    type  subjective semiology she experiences ti...       0.788950
# 587   feels off wave rushing down her body then full...       0.783057
# 1071   type convulsion subjective semiology her nose...       0.781636
#
#       Probability_1  Actual_Label
# 586        0.176910             0
# 1104       0.178149             1
# 677        0.179213             1
# 79         0.180327             1
# 73         0.180781             0
# 639        0.201012             1
# 122        0.204231             1
# 658        0.211050             1
# 587        0.216943             0
# 1071       0.218364             1
